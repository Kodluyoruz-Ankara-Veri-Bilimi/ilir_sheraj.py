# %% [markdown]
# # Homoework 3

# %%
import os
os.getcwd()
os.chdir('/home/ilirsheraj/Ankara Bootcamp/Week 3')
os.getcwd()
# Out:
# '/home/ilirsheraj/Ankara Bootcamp/Week 3'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm
import pylab
import statsmodels.api as sm

# %%
# Upload the data sheet in excel format
df = pd.read_excel ("HW_Data_Set.xlsx")
df.head()
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
#     ind_428  20_target  50_target  90_target
# ...

# %%
# Dimesnions of the data set
df.shape
# Out:
# (6167, 136)

# %% [markdown]
# The Data Set consistes of 6167 observations and 136 variables

# %%
# No NAN values!
import numpy
x = df.dropna()
x.shape
# Out:
# (6167, 136)

# %%
# Difficlult to deal with all the data at once, at least computationally, 
# so lets cut them into pieces and find what is continous and categorical

# %%
df1 = df.iloc[:, 0:45]
df1.head()
df1.describe()
# Out:
#              ind_5        ind_6        ind_8        ind_9       ind_10  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000
# mean     -0.803146    -0.803470    48.388890    48.289282     0.099609
# std      23.624403    23.624144    36.388526    36.478009    60.414625
# min    -131.000000  -131.000000     0.000000     0.000000  -100.000000
# 25%     -14.000000   -14.000000    14.285714    14.285714   -50.000000
# 50%       0.000000     0.000000    50.000000    50.000000     0.000000
# 75%      13.000000    13.000000    85.714286    85.714286    57.142857
# max      76.000000    76.000000   100.000000   100.000000   100.000000
#
#             ind_12       ind_13       ind_14       ind_15       ind_16  ...  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000  ...
# mean     49.488867   -18.497518    11.771485    11.773550    11.773392  ...
# std      12.198722    68.281120     6.803997     5.786089     4.970499  ...
# ...

# %%
plt.rcParams["figure.figsize"] = (20,15)
df1.hist(bins=20)
plt.show()

# %%
#H0: Normal Distribution
#H1: Not Normal Distribution
#Based on p-value (p=0.785), it is normal\

# %%
stat, p = shapiro(df1[["ind_39"]])
print(stat, p)
# Out:
# 0.994570255279541 1.5838091404238135e-14

# %%
# Apply Shapiro to see whether they are normally distributed   
from scipy.stats import shapiro
from scipy import stats
for column in df1:
    columnSeriesObj = df1[column]
    stat,p = shapiro(columnSeriesObj)
    print(stat, p)

# None of them is normally distributed
# Out:
# 0.9782097339630127 1.0259779393185995e-29
# 0.9782059192657471 1.0206398031805549e-29
# 0.8920465707778931 0.0
# 0.8908926248550415 0.0
# 0.9411660432815552 3.923635700109488e-44
# 0.9971137642860413 1.585031550455085e-09
# 0.8379719257354736 0.0
# 0.8725690841674805 0.0
# 0.9279128313064575 0.0
# 0.954002857208252 2.8084823821997984e-40
# 0.9621195793151855 2.263703277652185e-37
# 0.9522640705108643 7.587470664933155e-41
# 0.9735172390937805 2.604777638113519e-32
# 0.981923520565033 2.457128386068457e-27
# 0.9841470718383789 9.978972738207598e-26
# 0.8012078404426575 0.0
# 0.8696290254592896 0.0
# 0.8282515406608582 0.0
# 0.8785481452941895 0.0
# 0.9313709139823914 0.0
# 0.6397028565406799 0.0
# 0.9512662887573242 3.6425352281659295e-41
# 0.9909265637397766 1.8239827522692085e-19
# 0.9949207305908203 6.077217451060796e-14
# 0.9963933825492859 3.73440514622736e-11
# 0.9959304928779602 4.2518631844512544e-12
# 0.995124340057373 1.3652653226697842e-13
# ...

# %%
df2 = df.iloc[:, 46:90]
df2.head()
df2.describe()
# Out:
#             ind_58       ind_61       ind_62       ind_65       ind_67  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000
# mean      0.108481     0.108318    -0.055294    -0.495379     0.113021
# std       4.744296     3.516092    12.105387    11.908613     2.575623
# min     -22.000000   -14.000000   -36.000000   -32.000000    -8.000000
# 25%      -2.000000    -2.000000   -11.000000   -11.000000    -2.000000
# 50%       0.000000     0.000000     2.000000    -5.000000     0.000000
# 75%       2.000000     2.000000    11.000000    11.000000     2.000000
# max      37.000000    23.000000    31.000000    28.000000    13.000000
#
#             ind_70       ind_71       ind_74       ind_77       ind_82  ...  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000  ...
# mean      0.110589    -0.856494    -0.963029    -1.046052     0.087725  ...
# std       2.138513    11.766873    11.739521    11.719177     0.982621  ...
# ...

# %%
plt.rcParams["figure.figsize"] = (20,15)
df2.hist(bins=20)
plt.show()

# %%
df22 = df2.drop(["ind_109"], axis = 1)
for column in df22:
    columnSeriesObj = df22[column]
    stat,p = shapiro(columnSeriesObj)
    print(stat, p)

#None is NOrmally Distributed
# Out:
# 0.952899694442749 1.2187232874079367e-40
# 0.9682306051254272 7.771553607608563e-35
# 0.9094980955123901 0.0
# 0.8786787986755371 0.0
# 0.9756988883018494 3.7491301460719297e-31
# 0.9736979007720947 3.2269344719091083e-32
# 0.8334892988204956 0.0
# 0.819182813167572 0.0
# 0.8083401322364807 0.0
# 0.9040065407752991 0.0
# 0.7774912714958191 0.0
# 0.7116020917892456 0.0
# 0.9331145286560059 0.0
# 0.9825266003608704 6.474998813817242e-27
# 0.9767838716506958 1.5143143286049965e-30
# 0.986641526222229 1.0461796016672347e-23
# 0.9232949018478394 0.0
# 0.9451177716255188 5.086713425499086e-43
# 0.9844160676002502 1.603439045730778e-25
# 0.9956033825874329 1.0037885236555133e-12
# 0.9866476655006409 1.0590330645986343e-23
# 0.874139130115509 0.0
# 0.9258812069892883 0.0
# 0.9945852756500244 1.6758712879883994e-14
# 0.9939162135124207 1.4916758420916582e-15
# 0.9670301675796509 2.3103912421453448e-35
# 0.9917275905609131 1.6150049021389714e-18
# 0.9971036911010742 1.4986981655695786e-09
# ...

# %%
df3 = df.iloc[:, 91:136]
df3.head()
df3.describe()
# Out:
#            ind_239      ind_241      ind_243      ind_309      ind_310  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000
# mean      0.000071    90.049080     1.088305    -0.000032    -0.422692
# std       0.000143    31.330872     0.379271     0.000068     0.439721
# min       0.000000     0.000000     0.000000    -0.000742    -1.924803
# 25%       0.000014   100.032429     1.178772    -0.000026    -0.689339
# 50%       0.000028   100.277179     1.229946    -0.000013    -0.178707
# 75%       0.000073   101.086856     1.237501    -0.000006    -0.074333
# max       0.002555   104.767058     1.254120     0.000000     0.000000
#
#            ind_311      ind_313      ind_315      ind_316      ind_318  ...  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000  ...
# mean     95.137008     1.152460    -0.674508    80.624985     0.980187  ...
# std      18.305353     0.222516     0.778421    38.593195     0.469599  ...
# ...

# %%
plt.rcParams["figure.figsize"] = (20,15)
df3.hist(bins=20)
plt.show()

# %%
df32 = df3.drop(["ind_420","ind_422"], axis = 1)
for column in df32:
    columnSeriesObj = df32[column]
    stat,p = shapiro(columnSeriesObj)
    print(stat, p)

# Again none is normally distributed
# Out:
# 0.41737914085388184 0.0
# 0.3902106285095215 0.0
# 0.41250860691070557 0.0
# 0.43715542554855347 0.0
# 0.8382226824760437 0.0
# 0.23232299089431763 0.0
# 0.26646900177001953 0.0
# 0.805843710899353 0.0
# 0.4927051067352295 0.0
# 0.5152161121368408 0.0
# 0.5913078188896179 0.0
# 0.6002107858657837 0.0
# 0.6830156445503235 0.0
# 0.4069631099700928 0.0
# 0.5369133353233337 0.0
# 0.3345850706100464 0.0
# 0.3520559072494507 0.0
# 0.15943241119384766 0.0
# 0.10284405946731567 0.0
# 0.10020428895950317 0.0
# 0.1052100658416748 0.0
# 0.022349953651428223 0.0
# 0.02492547035217285 0.0
# 0.020496070384979248 0.0
# 0.948029637336731 3.651783798030473e-42
# 0.9635838866233826 8.533264619898827e-37
# 0.8852949142456055 0.0
# 0.9483582973480225 4.589252470663776e-42
# 0.9606602191925049 6.277960052618542e-38
# 0.9606624841690063 6.290172648994825e-38
# 0.9806866645812988 3.628186718375713e-28
# 0.9328164458274841 0.0
# 0.9426982998847961 1.0509738482436128e-43
# ...

# %%
df4 = df[["20_target", "50_target", "90_target"]]
plt.rcParams["figure.figsize"] = (20,15)
df4.hist(bins=20)
plt.show()

# %%
df_new = df.drop(["ind_109", "ind_420", "ind_422", "20_target", "90_target"], axis = 1)
df_new.head()
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_407  ind_410   ind_412  ind_414  ind_416  ind_418  \
# 0   17.62   11.73  ...      -23      -27  0.002371      2.0    -49.6      -54
# 1   18.16   12.22  ...      -16      -31  0.003074      0.8    -55.6      -60
# 2   17.86   12.28  ...      -10      -30  0.003561      2.7    -58.4      -60
# 3   14.76   12.61  ...      -10      -30  0.004366      0.9    -61.8      -65
# 4   11.92   14.25  ...      -24      -45  0.004198      0.1    -79.8      -86
#
#    ind_424   ind_426   ind_428  50_target
# ...

# %%
conda install -c conda-forge pingouin
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ilirsheraj/anaconda3
#
#   added / updated specs:
#     - pingouin
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     littleutils-0.2.2          |             py_0          10 KB  conda-forge
#     outdated-0.2.0             |             py_0           8 KB  conda-forge
#     pandas-flavor-0.2.0        |             py_0           8 KB  conda-forge
#     pingouin-0.3.6             |             py_0         169 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     tabulate-0.8.7             |     pyh9f0ad1d_0          24 KB  conda-forge
#     xarray-0.16.0              |             py_0         514 KB  conda-forge
# ...

# %%
import pingouin as pg
import seaborn as sns
from scipy.stats import pearsonr
# Calculate the Pearson correlation target_50 and everything else
corr = pg.pairwise_corr(df_new, columns=[['50_target'], df_new.iloc[:, 0:130]], method='pearson')

# %%
# Sort by r-value
corr.sort_values(by=['r'])[['X', 'Y', 'n', 'r', 'p-unc']]
# Out:
#              X        Y     n         r         p-unc
# 101  50_target  ind_324  6167 -0.110802  2.628037e-18
# 126  50_target  ind_418  6167 -0.101488  1.361592e-15
# 18   50_target   ind_26  6167 -0.084275  3.389810e-11
# 103  50_target  ind_330  6167 -0.075589  2.793435e-09
# 50   50_target   ind_67  6167 -0.069859  3.982194e-08
# ..         ...      ...   ...       ...           ...
# 9    50_target   ind_16  6167  0.101774  1.132716e-15
# 104  50_target  ind_332  6167  0.104057  2.565122e-16
# 10   50_target   ind_17  6167  0.121097  1.387363e-21
# 11   50_target   ind_18  6167  0.127057  1.290719e-23
# 123  50_target  ind_412  6167  0.127234  1.119352e-23
#
# [130 rows x 5 columns]

# %%
# sort by p-value
corr.sort_values(by=['p-unc'])[['X', 'Y', 'n', 'r', 'p-unc']]
# Out:
#              X        Y     n         r         p-unc
# 123  50_target  ind_412  6167  0.127234  1.119352e-23
# 11   50_target   ind_18  6167  0.127057  1.290719e-23
# 10   50_target   ind_17  6167  0.121097  1.387363e-21
# 101  50_target  ind_324  6167 -0.110802  2.628037e-18
# 104  50_target  ind_332  6167  0.104057  2.565122e-16
# ..         ...      ...   ...       ...           ...
# 82   50_target  ind_188  6167  0.003308  7.950792e-01
# 20   50_target   ind_28  6167 -0.002270  8.585404e-01
# 57   50_target   ind_88  6167  0.001783  8.886880e-01
# 77   50_target  ind_168  6167 -0.001361  9.148743e-01
# 22   50_target   ind_30  6167  0.001090  9.317696e-01
#
# [130 rows x 5 columns]

# %%
# Plot them in a correlation heatmap
corrs = df_new.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', mask=mask, square=True, vmin=-.8, vmax=.8)
plt.title('Correlation matrix for all variables')
plt.show()

#Lots of colinearity

# %%
# First create a regression model
X = df_new.drop(["50_target"], axis = 1)
Y = df_new["50_target"]

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
lm1 = sm.OLS(Y, X)

# %%
model1 = lm1.fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              50_target   R-squared (uncentered):                   0.169
# Model:                            OLS   Adj. R-squared (uncentered):              0.152
# Method:                 Least Squares   F-statistic:                              9.476
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                   1.50e-159
# Time:                        17:49:55   Log-Likelihood:                         -30047.
# No. Observations:                6167   AIC:                                  6.035e+04
# Df Residuals:                    6037   BIC:                                  6.123e+04
# Df Model:                         130
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
mod_table = model1.summary().tables[1]
mod_table
# Many variables show significance
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# Remove non-significant variables to increase the power of the model
df_clean = df_new[["ind_8", "ind_9", "ind_10", "ind_18", "ind_31", "ind_33", "ind_37", "ind_47", "ind_50",
                   "ind_51", "ind_71", "ind_74", "ind_77", "ind_82", "ind_130", "ind_142", "ind_147", "ind_153",
                  "ind_156", "ind_225", "ind_228", "ind_234", "ind_237", "ind_241", "ind_243", "ind_310", "ind_311",
                  "ind_313", "ind_315", "ind_321", "ind_324", "ind_332", "ind_334", "ind_338", "ind_349", "ind_387",
                  "ind_392", "ind_412", "ind_416", "ind_418", "ind_428", "50_target"]]
df_clean.head()
# Out:
#    ind_8      ind_9     ind_10  ind_18      ind_31      ind_33      ind_37  \
# 0  100.0  85.714286  14.285714  9.1100  150.505806  158.009516  184.819232
# 1  100.0  78.571429  21.428571  9.2225  156.903278  169.720843  191.985663
# 2  100.0  71.428571  28.571429  9.3125  154.452274  175.947530  197.993551
# 3  100.0  64.285714  35.714286  9.4150  139.695620  171.688382  200.370912
# 4  100.0  57.142857  42.857143  9.8925  168.275524  208.017747  223.561880
#
#    ind_47  ind_50  ind_51  ...   ind_334   ind_338  ind_349   ind_387  \
# 0     -36     -71     -93  ... -0.000091  1.197238      0.0 -3.731343
# 1     -38     -73     -96  ... -0.000091  1.197328      0.0 -1.369863
# 2     -36     -72     -95  ... -0.000091  1.197419      0.0 -4.278922
# 3     -37     -74     -97  ... -0.000091  1.197509      0.0 -1.355422
# 4     -53     -92    -115  ... -0.000091  1.197600      0.0 -0.116144
#
#      ind_392   ind_412  ind_416  ind_418   ind_428  50_target
# ...

# %%
X = df_clean.drop(["50_target"], axis = 1)
Y = df_clean["50_target"]
lm_clean = sm.OLS(Y, X)
model2 = lm_clean.fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              50_target   R-squared (uncentered):                   0.135
# Model:                            OLS   Adj. R-squared (uncentered):              0.129
# Method:                 Least Squares   F-statistic:                              23.32
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                   2.58e-160
# Time:                        17:50:19   Log-Likelihood:                         -30172.
# No. Observations:                6167   AIC:                                  6.043e+04
# Df Residuals:                    6126   BIC:                                  6.070e+04
# Df Model:                          41
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
mod_table2 = model2.summary().tables[1]
mod_table2
# Many variables show significance
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
clean_2 = df_clean.drop(["ind_31", "ind_51", "ind_71", "ind_349", "ind_387", "ind_392", "ind_428"], axis = 1)
X = clean_2.drop(["50_target"], axis = 1)
Y = clean_2["50_target"]
lm_clean2 = sm.OLS(Y, X)
model3 = lm_clean2.fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              50_target   R-squared (uncentered):                   0.133
# Model:                            OLS   Adj. R-squared (uncentered):              0.129
# Method:                 Least Squares   F-statistic:                              27.78
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                   5.49e-163
# Time:                        17:56:29   Log-Likelihood:                         -30178.
# No. Observations:                6167   AIC:                                  6.042e+04
# Df Residuals:                    6133   BIC:                                  6.065e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
corrs = clean_2.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', mask=mask, square=True, vmin=-.4, vmax=.4)
plt.title('Correlation matrix')
plt.show()
# There is a lot of multicolinearity

# %%
# For prediction, 30% for testing
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X = clean_2.drop(["50_target"], axis = 1)
Y = clean_2["50_target"]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1850, random_state = 42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4317, 34)
# (4317,)
# (1850, 34)
# (1850,)

# %%
lm_train = sm.OLS(y_train, X_train)

# %%
model_train = lm_train.fit()
model_train.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              50_target   R-squared (uncentered):                   0.143
# Model:                            OLS   Adj. R-squared (uncentered):              0.136
# Method:                 Least Squares   F-statistic:                              20.98
# Date:                Thu, 23 Jul 2020   Prob (F-statistic):                   1.57e-117
# Time:                        17:56:57   Log-Likelihood:                         -21103.
# No. Observations:                4317   AIC:                                  4.227e+04
# Df Residuals:                    4283   BIC:                                  4.249e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import numpy as np
import statsmodels.api as sm
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For prediction, 30% for testing
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X = clean_2.drop(["50_target"], axis = 1)
Y = clean_2["50_target"]
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1850, random_state = 42)
lm4 = LinearRegression()
model4 = lm4.fit(X_train, y_train)
model4.score(X_train, y_train)
# Out:
# 0.1380030088804921

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_train, model4.predict(X_train)))
# Out:
# 32.07584273497441

# %%
np.sqrt(mean_squared_error(y_test, model4.predict(X_test)))
# Out:
# 32.76538764880121

# %%
cross_val_score(model4, X_train, y_train, cv = 10, scoring = "r2").mean()
# Out:
# 0.11831534542182687

# %%
np.sqrt(-cross_val_score(model4,  X_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 32.379495581957244

# %%
np.sqrt(-cross_val_score(model4, X_test,  y_test, cv = 10,  scoring = "neg_mean_squared_error")).mean()
# Out:
# 33.00179328406982
